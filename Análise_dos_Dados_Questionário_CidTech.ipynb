# %% [markdown]
# #   <font color="#5A32EA">Análise de Dados Questionário - CidTech</font>
#
# <img src="https://github.com/Paresqui/CidTech/blob/112e48eb6812abffb5471951a1f7348ed55e6f98/img1.png?raw=true:, width=100" alt="My Image" width=1800>

# %% [markdown]
# ##   <font color="#5A32EA">Contexto</font>
#
#
# Neste notebook, irei analisar os dados referentes ao questionário idealizado pelo squad CidTech, e ver quais *insights* podem ser extraídos a partir desses dados, irei realizar plotagens de gráficos com Seaborn para melhor interatividade e visualização de outros tipos de gráficos.
#
# <font color="#2D35A8">[by Gabriela L. Paresqui](https://github.com/Paresqui)</font>

# %% [markdown]
# ##   <font color="#5A32EA">Leitura dos Dados</font>

# %%
#Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from pandas_profiling import ProfileReport
mpl.style.use('ggplot')
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %%
#Importando a base de dados
df = pd.read_excel("Pesquisa - Como aumentar a participação cidadã nas decisões governamentais (respostas).xlsx")

# %%
#Exibindo as 5 primeiras linhas
df.head()
# Out:
#      Carimbo de data/hora Qual é a sua idade?  \
# 0 2022-08-19 15:13:07.896          25-34 anos
# 1 2022-08-19 15:45:49.275          25-34 anos
# 2 2022-08-19 15:52:07.788          18-24 anos
# 3 2022-08-19 15:55:23.218          25-34 anos
# 4 2022-08-19 15:58:06.959          25-34 anos
#
#                  Com qual gênero você se identifica?  \
# 0  Homem Cis (se identifica com seu gênero de nas...
# 1  Homem Cis (se identifica com seu gênero de nas...
# 2  Mulher Cis (se identifica com seu gênero de na...
# 3  Homem Cis (se identifica com seu gênero de nas...
# 4  Mulher Cis (se identifica com seu gênero de na...
#
#   Em qual região você mora? Qual é  o seu nível de escolaridade?  \
# 0                   Sudeste                   Graduação Completa
# 1                   Sudeste                 Graduação Incompleta
# 2                   Sudeste                   Graduação Completa
# 3              Centro-Oeste                   Graduação Completa
# ...

# %%
#Quantidade de linhas e colunas do dataframe
rows, columns = df.shape

print(f'Esse dataset possui {rows} linhas e {columns} colunas')
# Out:
# Esse dataset possui 116 linhas e 34 colunas

# %% [markdown]
# ##   <font color="#5A32EA">Preparação dos Dados</font>

# %%
#Excluindo colunas desnecessárias 
df.drop(['Qual o seu nome?.1', 'Nós temos interesse em saber mais detalhes sobre suas opiniões a respeito desse tema. Você gostaria de participar de uma conversa rápida com nossa equipe? Se sim, deixe suas informações de contato a seguir:.1', 'Nos informe um meio para entrar em contato (E-mail, WhatsApp).1','Nós temos interesse em saber mais detalhes sobre suas opiniões a respeito desse tema. Você gostaria de participar de uma conversa rápida com nossa equipe? Se sim, deixe suas informações de contato a seguir:.2','Qual o seu nome?.2','Nos informe um meio para entrar em contato (E-mail, WhatsApp)','Qual o seu nome?','Nós temos interesse em saber mais detalhes sobre suas opiniões a respeito desse tema. Você gostaria de participar de uma conversa rápida com nossa equipe? Se sim, deixe suas informações de contato a seguir:','Nos informe um meio para entrar em contato (E-mail, WhatsApp).2'], axis=1, inplace=True)

# %%
#Quantidade de linhas e colunas do dataframe
rows, columns = df.shape

print(f'Esse dataset possui {rows} linhas e {columns} colunas')
# Out:
# Esse dataset possui 116 linhas e 25 colunas

# %%
#Renomeando as colunas para melhor entendimento do dataframe
df.rename(columns={'Carimbo de data/hora': 'Data','Com qual gênero você se identifica?': 'Gênero', 'Situação prática: Na última semana um buraco na rua tem atrapalhado a passagem de carros e pedestres, mas nenhuma resolução foi iniciada. Como você considera apropriado proceder? (Você pode selecionar mais de uma opção).2':'Situação Prática2','Por quais meios você acessa informações e conhecimentos para orientar suas ações cidadãs?  (Você pode selecionar mais de uma opção).2':'Por quais meios você acessa informações e conhecimentos para orientar suas ações cidadãs?','Qual é  o seu nível de escolaridade?':'Escolaridade','Em qual região você mora?':'Região','Qual é a sua idade?':'Idade'}, inplace = True)

# %%
#Exibindo os nomes de todas as colunas 
df.columns.value_counts().index
# Out:
# Index(['Data', 'Você gostaria de participar das decisões governamentais?',
#        'Como você considera seu nível de entendimento sobre as informações encontradas nos meios citados anteriormente?.2',
#        'Por quais meios você acessa informações e conhecimentos para orientar suas ações cidadãs?',
#        'Situação Prática2',
#        'Dentre as opções abaixo, qual poderia estimular sua vontade de conhecer mais sobre temas de politica e cidadania?   (Você pode selecionar mais de uma opção).1',
#        'Como você considera seu nível de entendimento sobre as informações encontradas nos meios citados anteriormente?.1',
#        'Por quais meios você acessa informações e conhecimentos para orientar suas ações cidadãs?  (Você pode selecionar mais de uma opção).1',
# ...

# %%
#Exibindo as principais informações sobre o dataframe e suas colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 25 columns):
#  #   Column                                                                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                         --------------  -----
#  0   Data                                                                                                                                                                                                                           116 non-null    datetime64[ns]
# ...

# %% [markdown]
# ##   <font color="#5A32EA">Transformação dos Dados</font>

# %%
#Verificando se há dados duplicados
duplicados = df.duplicated().sum()
print(f'O dataframe possui {duplicados} dados duplicados.')
# Out:
# O dataframe possui 0 dados duplicados.

# %%
#Estatística descritiva simples.
df.describe(include="all")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                               Data       Idade  \
# count                          116         116
# unique                         116           6
# top     2022-08-19 15:13:07.896000  25-34 anos
# freq                             1          70
# first   2022-08-19 15:13:07.896000         NaN
# last    2022-08-26 15:49:07.591000         NaN
#
#                                                    Gênero   Região  \
# count                                                 116      116
# unique                                                  3        5
# top     Mulher Cis (se identifica com seu gênero de na...  Sudeste
# ...
